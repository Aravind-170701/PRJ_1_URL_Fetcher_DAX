# %% [markdown]
# # Google Search Engine Scrape using SERP API

# %%
# Importing Libraries

import numpy as np
import pandas as pd
import traceback
from serpapi import GoogleSearch

# %%
# Filtering Dataframe that do not have a website URL but do contain
# State, Profession and Place type information

dataframe = pd.read_csv("input_data.csv",usecols=["infogroup_id","name","place_type","phone","street","city","labels.state","website","labels.primary_sic_code_id","labels.location_parent_relationship"])

dataframe = dataframe[dataframe['website'].isna()]

filtered_dataframe = dataframe[(~dataframe['labels.state'].isna()) & (~dataframe['labels.primary_sic_code_id'].isna()) & (~dataframe['place_type'].isna())]

filtered_dataframe.reset_index(inplace = True, drop = True)

filtered_dataframe.head()
# Out:
#    infogroup_id   place_type                                name  \
# 0     538104035  independent  Wachter's Chair Caning & Furniture
# 1     718638652  independent      Always There Homecare-the Palm
# 2     742117988   individual                O'Neill, Christopher
# 3     746285930  independent                        Secuepay Inc
# 4     713083515  independent              Dandy Handyman Service
#
#                  street              city labels.state  \
# 0           615 Gear St            Galena     Illinois
# 1                   NaN          Atlantis      Florida
# 2   2790 N Academy Blvd  Colorado Springs     Colorado
# 3  30 Pecan Course Loop             Ocala      Florida
# 4       255 Wavetree Dr           Roswell      Georgia
#
#   labels.location_parent_relationship           labels.primary_sic_code_id  \
# 0                    Primary Business                         Chair Caning
# 1                    Primary Business                      Health Services
# 2             Professional Individual                       Social Workers
# 3                    Primary Business         Nonclassified Establishments
# 4                    Primary Business  Miscellaneous Personal Services NEC
#
#             phone website
# 0  (815) 777-0945     NaN
# 1  (561) 570-6129     NaN
# 2  (719) 444-0250     NaN
# 3             NaN     NaN
# 4  (770) 518-7677     NaN

# %%
# Selecting a random sample of length 50 out of the filtered dataframe 
# to test it on SERP API

filtered_dataframe = filtered_dataframe[filtered_dataframe['place_type'] == 'individual'].sample(50)

# %%
filtered_dataframe = filtered_dataframe[filtered_dataframe.name.str.contains('.*,.*', regex= True, na=False)]
filtered_dataframe
# Out:
#        infogroup_id  place_type                             name  \
# 5704      741974114  individual                   Bangura, Doris
# 39813     760835559  individual               Stevelinck, Sydney
# 1624      725724002  individual           Schenne, Jennifer B DO
# 60783     769685384  individual       Pinto, Nasstasijia, Noelia
# 31416     756815222  individual                Kremer, Alexander
# 73341     744404996  individual               Gunderson, Kristen
# 6087      739477242  individual                 Gallagher, Seema
# 56189     753887537  individual              Schumacher, Ross MD
# 44796     752750768  individual             Amipara, Ravindrakum
# 32337     764223262  individual         Katkov, William, Michael
# 26015     751719288  individual     Schiefelbein, Courtney A DMD
# 70821     742817413  individual                  Amedome, Enna I
# 17625     743795440  individual               Barkhurst, Megan T
# 1043      763627490  individual               Johnson, Elizabeth
# 10155     729298690  individual            Shamshad, Faisal A MD
# 73881     753895468  individual                 Sheaffer, Brenna
# 67828     734777326  individual               Thornton, Cherie L
# 20657     762960767  individual            Malik, Mansura, Tahir
# 35971            2278 N Penn Rd         Hatfield          Pennsylvania
# 39120                       NaN      Gainesville               Florida
# 20696         2501 Kentucky Ave          Paducah              Kentucky
# 49731         1712C E Broad Ave           Albany               Georgia
# 51292         704 Poinciana Ave            Mamou             Louisiana
# 16603         402 N Bryant Blvd       San Angelo                 Texas
# 1266             758 N State St             Caro              Michigan
# 29990            292 W Broadway         Paterson            New Jersey
#
#       labels.location_parent_relationship labels.primary_sic_code_id  \
# 5704                     Primary Business       Nurses-Practitioners
# 39813                    Primary Business        Physical Therapists
# 1624              Professional Individual      Physicians & Surgeons
# 60783             Professional Individual       Nurses-Practitioners
# 31416                    Primary Business                Acupuncture
# 73341                    Primary Business        Physical Therapists
# 6087                     Primary Business                Pharmacists
# 56189                    Primary Business      Physicians & Surgeons
# 44796                    Primary Business                Pharmacists
# 32337                    Primary Business             Social Workers
# 26015                    Primary Business                   Dentists
# 70821                    Primary Business       Nurses-Practitioners
# 17625                    Primary Business       Nurses-Registered RN
# 1043                     Primary Business       Nurses-Practitioners
# 10155                    Primary Business      Physicians & Surgeons
# 73881                    Primary Business        Physical Therapists
# 67828                    Primary Business                 Counselors
# 20657                    Primary Business       Nurses-Practitioners
# 19761             Professional Individual      Physicians Assistants
# 30351                    Primary Business                   Dentists
# 20478                    Primary Business      Physicians & Surgeons
# 4935                     Primary Business      Physicians & Surgeons
# 38291             Professional Individual                Pharmacists
# 52745                    Primary Business                 Pharmacies
# 3262                     Primary Business                 Counselors
# 60517                    Primary Business                 Counselors
# 11432                    Primary Business                   Dentists
# 20609             Professional Individual              Psychologists
# 51604                    Primary Business      Physicians & Surgeons
# 3584                     Primary Business              Veterinarians
# 74532                    Primary Business       Nurses-Registered RN
# 7909                     Primary Business      Physicians & Surgeons
# 72565                    Primary Business      Physicians & Surgeons
# 66439                    Primary Business                 Counselors
# 35971             Professional Individual        Physical Therapists
# 39120                    Primary Business      Physicians & Surgeons
# 20696             Professional Individual       Nurses-Practitioners
# 49731                    Primary Business       Nurses-Practitioners
# 51292             Professional Individual           Chiropractors DC
# 16603             Professional Individual       Nurses-Practitioners
# 1266              Professional Individual           Chiropractors DC
# 29990                    Primary Business       Nurses-Registered RN
#
#                 phone website
# 5704   (817) 690-5032     NaN
# 39813  (586) 569-1378     NaN
# 1624   (928) 442-8710     NaN
# 60783  (718) 656-1245     NaN
# 31416  (267) 753-5337     NaN
# 73341  (281) 299-7505     NaN
# 6087   (864) 587-9486     NaN
# 56189  (205) 996-5864     NaN
# 44796  (214) 516-4871     NaN
# 32337  (619) 221-6393     NaN
# 26015  (646) 770-2091     NaN
# 70821  (281) 467-5122     NaN
# 17625  (813) 382-8392     NaN
# 1043   (636) 887-3020     NaN
# 10155  (712) 279-3500     NaN
# 73881  (717) 524-6410     NaN
# 67828  (419) 675-2243     NaN
# 20657  (678) 849-2732     NaN
# 19761  (317) 621-6725     NaN
# 30351  (312) 576-5570     NaN
# 20478             NaN     NaN
# 4935              NaN     NaN
# 38291  (781) 321-1017     NaN
# 52745  (787) 812-3030     NaN
# 3262   (305) 262-5555     NaN
# 60517  (931) 215-3232     NaN
# 11432  (586) 718-4607     NaN
# 20609  (785) 357-0580     NaN
# 51604  (808) 965-0323     NaN
# 3584   (205) 836-9802     NaN
# 74532  (202) 733-7747     NaN
# 7909              NaN     NaN
# 72565             NaN     NaN
# 66439  (513) 221-4500     NaN
# 35971  (215) 997-9898     NaN
# 39120  (904) 514-8363     NaN
# 20696             NaN     NaN
# 49731  (229) 639-3100     NaN
# 51292  (337) 468-3337     NaN
# 16603             NaN     NaN
# 1266   (989) 672-4141     NaN
# 29990  (973) 930-9530     NaN

# %%
# Scraper Class which scrapes search engine 
# to fetch website URL based on the given query
# using SERP API

class SearchEngineScraper:
    
    def __init__(self):
        
        self.searchParams = {
            "engine": "google",
            "q": "",
            "location": "",
            "google_domain": "google.com",
            "gl": "us",
            "hl": "en",
            "api_key": "69190367cce22584a14d6cfe1de75811df9bfa1bab44e4a655b53ffe3eb7a279"
        }
        

    def google_scrape(self, query: str, location: str) -> str:
        
        self.searchParams['q'] = query
        self.searchParams['location'] = location

        client = GoogleSearch(self.searchParams)
        results = client.get_dict()
        organic_results = results["organic_results"]
        
        return organic_results[0]['link']

# %%
scraper = SearchEngineScraper()

for i,row in filtered_dataframe.iterrows():
    
    query = row['name'] + " " +  row['labels.primary_sic_code_id'] + " " + 'Linkedin'
    location = row['city']
    
    try:
        linkedin_profile_link = scraper.google_scrape(query,location)
        print(linkedin_profile_link)
    except:
        traceback.print_exc()
        break
# Out:
# https://serpapi.com/search
# https://www.linkedin.com/in/doris-bangura-a52926a8
# https://serpapi.com/search
# https://www.linkedin.com/in/sydney-stevelinck
# https://serpapi.com/search
# https://www.linkedin.com/in/jennifer-to-4175b913b
# https://serpapi.com/search
# https://www.linkedin.com/company/nurse-practitioner
# https://serpapi.com/search
# https://www.linkedin.com/in/alexander-sasha-kremer-92aa7aa2
# https://serpapi.com/search
# Traceback (most recent call last):
#   File "C:\Users\apidap\AppData\Local\Temp\ipykernel_24508\240206763.py", line 9, in <cell line: 3>
#     linkedin_profile_link = scraper.google_scrape(query,location)
#   File "C:\Users\apidap\AppData\Local\Temp\ipykernel_24508\3443309870.py", line 26, in google_scrape
#     results = client.get_dict()
#   File "C:\Users\apidap\AppData\Local\Programs\Python\Python39\lib\site-packages\serpapi\serp_api_client.py", line 103, in get_dict
#     return self.get_dictionary()
#   File "C:\Users\apidap\AppData\Local\Programs\Python\Python39\lib\site-packages\serpapi\serp_api_client.py", line 96, in get_dictionary
#     return dict(self.get_json())
#   File "C:\Users\apidap\AppData\Local\Programs\Python\Python39\lib\site-packages\serpapi\serp_api_client.py", line 83, in get_json
#     return json.loads(self.get_results())
#   File "C:\Users\apidap\AppData\Local\Programs\Python\Python39\lib\site-packages\serpapi\serp_api_client.py", line 70, in get_results
#     return self.get_response(path).text
#   File "C:\Users\apidap\AppData\Local\Programs\Python\Python39\lib\site-packages\serpapi\serp_api_client.py", line 59, in get_response
#     response = requests.get(url, parameter, timeout=self.timeout)
#   File "C:\Users\apidap\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#   File "C:\Users\apidap\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "C:\Users\apidap\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\apidap\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\apidap\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "C:\Users\apidap\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\apidap\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\apidap\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\apidap\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 1377, in getresponse
#     response.begin()
#   File "C:\Users\apidap\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\apidap\AppData\Local\Programs\Python\Python39\lib\http\client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\apidap\AppData\Local\Programs\Python\Python39\lib\socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\apidap\AppData\Local\Programs\Python\Python39\lib\ssl.py", line 1242, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\apidap\AppData\Local\Programs\Python\Python39\lib\ssl.py", line 1100, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt
